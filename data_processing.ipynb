# %% [markdown]
# ## Processing the data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
import sys
import sklearn
sys.path.append(os.path.join(os.path.abspath(".."), "code"))
from sklearn.preprocessing import MinMaxScaler

# %%
df = pd.read_csv("data/clothing_sustainability.csv")
df
# Out:
#                Company     Product_Type  Production_Year  \
# 0                 Zara        Polyester             2020
# 1                 Zara            Nylon             2019
# 2                 Zara    Recycled_Poly             2021
# 3                 Zara           Cotton             2018
# 4                 Zara  Synthetic_Blend             2022
# ...                ...              ...              ...
# 6951            Adidas           Tencel             2018
# 6952  Urban Outfitters       Microfiber             2019
# 6953  Urban Outfitters   Organic_Cotton             2019
# 6954            Adidas       Microfiber             2020
# 6955  Urban Outfitters            Nylon             2020
#
#       Greenhouse_Gas_Emissions  Pollutants_Emitted  Water_Consumption  \
# 0                         5000                  20               7500
# 1                         3000                  15               5000
# 2                         3500                  18               6000
# 3                         2000                  10               4500
# 4                         6000                  25               8000
# ...                        ...                 ...                ...
# 6951                      3218                  21               7536
# 6952                      2622                  11               5267
# 6953                      5920                  24               4321
# 6954                      2897                  16               4125
# 6955                      3428                  25               7005
#
#       Energy_Consumption  Waste_Generation  Sales_Revenue
# 0                   1200               300         500000
# 1                    900               200         450000
# 2                   1100               250         480000
# 3                    800               180         550000
# 4                   1500               350         600000
# ...                  ...               ...            ...
# 6951                 902               192         523173
# 6952                 952               170         436096
# 6953                 982               177         489765
# 6954                1085               321         487443
# 6955                 906               336         552712
#
# [6956 rows x 9 columns]

# %%
# Check for missing values
df.isnull().sum()
# Out:
# Company                     0
# Product_Type                0
# Production_Year             0
# Greenhouse_Gas_Emissions    0
# Pollutants_Emitted          0
# Water_Consumption           0
# Energy_Consumption          0
# Waste_Generation            0
# Sales_Revenue               0
# dtype: int64

# %%
features = ['Greenhouse_Gas_Emissions', 'Pollutants_Emitted', 'Water_Consumption', 'Energy_Consumption', 'Waste_Generation']
df_features = df[features]

# %% [markdown]
# ## Scaling features using MinMaxScaler()

# %%
scaler = MinMaxScaler()
df_normalized = pd.DataFrame(scaler.fit_transform(df_features), columns=features)
df_normalized
# Out:
#       Greenhouse_Gas_Emissions  Pollutants_Emitted  Water_Consumption  \
# 0                     0.761905              0.6875            0.87500
# 1                     0.285714              0.3750            0.25000
# 2                     0.404762              0.5625            0.50000
# 3                     0.047619              0.0625            0.12500
# 4                     1.000000              1.0000            1.00000
# ...                        ...                 ...                ...
# 6951                  0.337619              0.7500            0.88400
# 6952                  0.195714              0.1250            0.31675
# 6953                  0.980952              0.9375            0.08025
# 6954                  0.261190              0.4375            0.03125
# 6955                  0.387619              1.0000            0.75125
#
#       Energy_Consumption  Waste_Generation
# 0                0.62500             0.750
# 1                0.25000             0.250
# 2                0.50000             0.500
# 3                0.12500             0.150
# 4                1.00000             1.000
# ...                  ...               ...
# 6951             0.25250             0.210
# 6952             0.31500             0.100
# 6953             0.35250             0.135
# 6954             0.48125             0.855
# 6955             0.25750             0.930
#
# [6956 rows x 5 columns]

# %% [markdown]
# ### Note that the higher the rating the more unsustainable

# %%
df_normalized['sustainability_rating'] = df_normalized.mean(axis=1)
df_normalized['sustainability_rating']
# Out:
# 0       0.739881
# 1       0.282143
# 2       0.493452
# 3       0.102024
# 4       1.000000
#           ...
# 6951    0.486824
# 6952    0.210493
# 6953    0.497240
# 6954    0.413238
# 6955    0.665274
# Name: sustainability_rating, Length: 6956, dtype: float64

# %%
# Classify the sustainability score into categories
def classify_sustainability(score):
    if score <= 0.25:
        return 'Highly Sustainable'
    elif 0.25 <= score < 0.5:
        return 'Moderately Sustainable'
    else:
        return 'Not Sustainable'

# Apply the classification
df_normalized['sustainability_category'] = df_normalized['sustainability_rating'].apply(classify_sustainability)

# %%
df_normalized
# Out:
#       Greenhouse_Gas_Emissions  Pollutants_Emitted  Water_Consumption  \
# 0                     0.761905              0.6875            0.87500
# 1                     0.285714              0.3750            0.25000
# 2                     0.404762              0.5625            0.50000
# 3                     0.047619              0.0625            0.12500
# 4                     1.000000              1.0000            1.00000
# ...                        ...                 ...                ...
# 6951                  0.337619              0.7500            0.88400
# 6952                  0.195714              0.1250            0.31675
# 6953                  0.980952              0.9375            0.08025
# 6954                  0.261190              0.4375            0.03125
# 6955                  0.387619              1.0000            0.75125
#
#       Energy_Consumption  Waste_Generation  sustainability_rating  \
# 0                0.62500             0.750               0.739881
# 1                0.25000             0.250               0.282143
# 2                0.50000             0.500               0.493452
# 3                0.12500             0.150               0.102024
# 4                1.00000             1.000               1.000000
# ...                  ...               ...                    ...
# 6951             0.25250             0.210               0.486824
# 6952             0.31500             0.100               0.210493
# 6953             0.35250             0.135               0.497240
# 6954             0.48125             0.855               0.413238
# 6955             0.25750             0.930               0.665274
#
#      sustainability_category
# 0            Not Sustainable
# 1     Moderately Sustainable
# 2     Moderately Sustainable
# 3         Highly Sustainable
# 4            Not Sustainable
# ...                      ...
# 6951  Moderately Sustainable
# 6952      Highly Sustainable
# 6953  Moderately Sustainable
# 6954  Moderately Sustainable
# 6955         Not Sustainable
#
# [6956 rows x 7 columns]

# %%
dfpt = df[['Company', 'Product_Type']]
combined_df = pd.concat([dfpt.reset_index(drop=True), df_normalized.reset_index(drop=True)], axis=1)
combined_df
# Out:
#                Company     Product_Type  Greenhouse_Gas_Emissions  \
# 0                 Zara        Polyester                  0.761905
# 1                 Zara            Nylon                  0.285714
# 2                 Zara    Recycled_Poly                  0.404762
# 3                 Zara           Cotton                  0.047619
# 4                 Zara  Synthetic_Blend                  1.000000
# ...                ...              ...                       ...
# 6951            Adidas           Tencel                  0.337619
# 6952  Urban Outfitters       Microfiber                  0.195714
# 6953  Urban Outfitters   Organic_Cotton                  0.980952
# 6954            Adidas       Microfiber                  0.261190
# 6955  Urban Outfitters            Nylon                  0.387619
#
#       Pollutants_Emitted  Water_Consumption  Energy_Consumption  \
# 0                 0.6875            0.87500             0.62500
# 1                 0.3750            0.25000             0.25000
# 2                 0.5625            0.50000             0.50000
# 3                 0.0625            0.12500             0.12500
# 4                 1.0000            1.00000             1.00000
# ...                  ...                ...                 ...
# 6951              0.7500            0.88400             0.25250
# 6952              0.1250            0.31675             0.31500
# 6953              0.9375            0.08025             0.35250
# 6954              0.4375            0.03125             0.48125
# 6955              1.0000            0.75125             0.25750
#
#       Waste_Generation  sustainability_rating sustainability_category
# 0                0.750               0.739881         Not Sustainable
# 1                0.250               0.282143  Moderately Sustainable
# 2                0.500               0.493452  Moderately Sustainable
# 3                0.150               0.102024      Highly Sustainable
# 4                1.000               1.000000         Not Sustainable
# ...                ...                    ...                     ...
# 6951             0.210               0.486824  Moderately Sustainable
# 6952             0.100               0.210493      Highly Sustainable
# 6953             0.135               0.497240  Moderately Sustainable
# 6954             0.855               0.413238  Moderately Sustainable
# 6955             0.930               0.665274         Not Sustainable
#
# [6956 rows x 9 columns]

# %%
# Save the processed data
combined_df.to_csv('processed_sustainability_ratings.csv', index=False)
